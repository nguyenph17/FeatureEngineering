# %% [markdown]
# # House Prices

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
from scipy import stats

from sklearn.impute import KNNImputer

#import feature_engine
from feature_engine.encoding import OrdinalEncoder

# %%
# import sys
# !{sys.executable} -m pip install feature_engine

# %% [markdown]
# ## Load dataset

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# !ln -s "/content/drive/MyDrive/AICamp/Feature engineering project"

# %%
# !ls "Feature engineering project"

# %%
# %cd "Feature engineering project"

# %%
# !dir
# Out:
#  Volume in drive H is Google Drive
#  Volume Serial Number is 1983-1116
#
#  Directory of H:\My Drive\AICamp\Feature engineering project
#
# 09/20/2022  04:46 PM    <DIR>          .
# 09/15/2022  01:14 PM    <DIR>          ..
# 09/15/2022  11:14 AM           203,809 house-prices-advanced-regression-techniques.zip
# 09/20/2022  04:46 PM           907,490 House-prices.ipynb
# 12/16/2019  04:33 AM            31,939 sample_submission.csv
# 12/16/2019  04:33 AM           460,676 train.csv
# 12/16/2019  04:33 AM           451,405 test.csv
# 12/16/2019  04:33 AM            13,370 data_description.txt
# 09/20/2022  04:42 PM    <DIR>          .ipynb_checkpoints
#                6 File(s)      2,068,689 bytes
#                3 Dir(s)   8,026,279,936 bytes free

# %% [markdown]
# ##### Unzip dataset

# %%
#!unzip "house-prices-advanced-regression-techniques.zip"

# %% [markdown]
# #### Load dataset

# %%
df_train = pd.read_csv("train.csv", index_col="Id")
df_test = pd.read_csv("test.csv", index_col="Id")

# %%
df_train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
df_test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461         NaN       0       6    2010        WD         Normal
# 1462        Gar2   12500       6    2010        WD         Normal
# 1463         NaN       0       3    2010        WD         Normal
# 1464         NaN       0       6    2010        WD         Normal
# 1465         NaN       0       1    2010        WD         Normal
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Util functions

# %%
def check_missing(col_name):
    n_missing = df_train[col_name].isna().sum()
    total = len(df_train[col_name])
    rate =  round((n_missing*1.0)/total, 4)
    print(f"The column {col_name} has {n_missing} missing values in total {total} ({rate})")

# %%
def plot_distributions(serie, dropna=True):
    fig, ax = plt.subplots(1,2, figsize=(16,4))
    serie = serie.dropna()
    sns.boxplot(serie, ax=ax[0])


    #sns.displot(np.array(df_train['LotFrontage'].dropna()))

    sns.distplot(serie, ax=ax[1], fit=stats.norm, fit_kws={"color":"red"})
    (mu, sigma) = stats.norm.fit(serie)
    plt.legend(['Normal Distribution \n ($\mu=$ {:.2f} and  $\sigma=$ {:.2f} )'.format(mu, sigma)],
                 loc='best', fancybox=True)
    plt.show()

# %% [markdown]
# ## I. Feature engineering

# %% [markdown]
# ### 1. EDA (Exploratory Data Analysis)

# %% [markdown]
# #### The shape of dataset

# %%
train_shape = df_train.shape
test_shape = df_test.shape

print(f"The train set has {train_shape[0]} rows and {train_shape[1]} columns (including target)!")
print(f"The test set has {test_shape[0]} rows and {test_shape[1]} columns!")
# Out:
# The train set has 1460 rows and 80 columns (including target)!
# The test set has 1459 rows and 79 columns!

# %%
n_features = test_shape[1]
print(f"There are {n_features} features in the dataset.")
# Out:
# There are 79 features in the dataset.

# %% [markdown]
# #### Data types in dataset

# %%
data_types = df_train.dtypes
print(f"There are {len(data_types.unique())} data types: {data_types.unique()} in dataset.")
print(f"Data type of column MSSubClass is {data_types['MSSubClass']}")
# Out:
# There are 3 data types: [dtype('int64') dtype('O') dtype('float64')] in dataset.
# Data type of column MSSubClass is int64

# %%
test_data_types = df_test.dtypes

# %%
missmatch_data_type_col = data_types.drop('SalePrice').compare(test_data_types)
missmatch_data_type_col
# Out:
#                self    other
# BsmtFinSF1    int64  float64
# BsmtFinSF2    int64  float64
# BsmtUnfSF     int64  float64
# TotalBsmtSF   int64  float64
# BsmtFullBath  int64  float64
# BsmtHalfBath  int64  float64
# GarageCars    int64  float64
# GarageArea    int64  float64

# %% [markdown]
# Get numeric/categorical columns

# %%
data_types.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
numerical_cols = df_train.select_dtypes(include=['int64', 'float64']).columns
print(f"There are {len(numerical_cols)} numerical columns")
numerical_cols[:10]
# Out:
# There are 37 numerical columns
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2'],
#       dtype='object')

# %%
categorical_cols = df_train.select_dtypes(include=['O']).columns
print(f"There are {len(categorical_cols)} categorical columns")
categorical_cols[:10]
# Out:
# There are 43 categorical columns
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1'],
#       dtype='object')

# %% [markdown]
# #### Matching data type for train/test
# Change data type of the columns in train set which mismatch with test set in order to match test set.
#
# Change data type of columns in train set missmatch_data_type_col to float64

# %%
new_data_types = {}
for col in missmatch_data_type_col.index:
    df_train[col] = df_train[col].astype(missmatch_data_type_col.loc['BsmtFinSF1', 'other'])
    print(df_train[col].dtypes)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
data_types = df_train.dtypes
data_types.drop('SalePrice').compare(test_data_types)
# Out:
# Empty DataFrame
# Columns: [self, other]
# Index: []

# %% [markdown]
# The data types are the same in train and test set

# %% [markdown]
# #### Checking missing values

# %%
def check_missing_values(df):
    missing_percent = df.isna().sum().sort_values(ascending=False) / len(df)
    return missing_percent

# %%
# Checking missing values on train set
na_train = check_missing_values(df_train)
na_train[:10]
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageYrBlt     0.055479
# GarageCond      0.055479
# GarageType      0.055479
# GarageFinish    0.055479
# dtype: float64

# %%
na_train[:20].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Checking missing values on train set
na_test = check_missing_values(df_test)
na_test[:10]
# Out:
# PoolQC          0.997944
# MiscFeature     0.965045
# Alley           0.926662
# Fence           0.801234
# FireplaceQu     0.500343
# LotFrontage     0.155586
# GarageYrBlt     0.053461
# GarageFinish    0.053461
# GarageQual      0.053461
# GarageCond      0.053461
# dtype: float64

# %%
na_test[:20].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
set(na_train[na_train>0].index).difference(set(na_test[na_test>0].index))
# Out:
# {'Electrical'}

# %%
missing_cols = na_train.index

# %% [markdown]
# #### Distribution of target

# %%
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df_train['SalePrice'].plot(kind='hist', bins=30, title='Distribution of target')
# Out:
# <AxesSubplot:title={'center':'Distribution of target'}, ylabel='Frequency'>

# %% [markdown]
# #### Correlation matrix

# %%
corr_matrix = df_train[numerical_cols].corr().round(2)
corr_matrix.head()
# Out:
#              MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# MSSubClass         1.00        -0.39    -0.14         0.03        -0.06
# LotFrontage       -0.39         1.00     0.43         0.25        -0.06
# LotArea           -0.14         0.43     1.00         0.11        -0.01
# OverallQual        0.03         0.25     0.11         1.00        -0.09
# OverallCond       -0.06        -0.06    -0.01        -0.09         1.00
#
#              YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  \
# MSSubClass        0.03          0.04        0.02       -0.07       -0.07  ...
# LotFrontage       0.12          0.09        0.19        0.23        0.05  ...
# LotArea           0.01          0.01        0.10        0.21        0.11  ...
# OverallQual       0.57          0.55        0.41        0.24       -0.06  ...
# OverallCond      -0.38          0.07       -0.13       -0.05        0.04  ...
#
#              WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# MSSubClass        -0.01        -0.01          -0.01      -0.04        -0.03
# LotFrontage        0.09         0.15           0.01       0.07         0.04
# LotArea            0.17         0.08          -0.02       0.02         0.04
# OverallQual        0.24         0.31          -0.11       0.03         0.06
# OverallCond       -0.00        -0.03           0.07       0.03         0.05
#
#              PoolArea  MiscVal  MoSold  YrSold  SalePrice
# MSSubClass       0.01    -0.01   -0.01   -0.02      -0.08
# LotFrontage      0.21     0.00    0.01    0.01       0.35
# LotArea          0.08     0.04    0.00   -0.01       0.26
# OverallQual      0.07    -0.03    0.07   -0.03       0.79
# OverallCond     -0.00     0.07   -0.00    0.04      -0.08
#
# [5 rows x 37 columns]

# %%
fig, ax = plt.subplots(figsize=(30, 30))
sns.heatmap(corr_matrix, cmap="YlGnBu", annot=True, ax=ax)
plt.show()

# %% [markdown]
# ### Missing data

# %% [markdown]
# #### Missing cols > 40%

# %% [markdown]
# Get columns with missing percentage greater than 40%

# %%
cols_with_gt_40_missing = set(na_test[na_test > 0.4].index).union(set(na_train[na_train > 0.4].index))
cols_with_gt_40_missing
# Out:
# {'Alley', 'Fence', 'FireplaceQu', 'MiscFeature', 'PoolQC'}

# %%
ignored_cols = []

# %% [markdown]
# ##### Alley column
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access

# %%
print(f"No of missing values of Alley column: {df_train['Alley'].isna().sum()} / {len(df_train)}  ({round(na_train['Alley'], 2)})")
# Out:
# No of missing values of Alley column: 1369 / 1460  (0.94)

# %% [markdown]
# **==>This is not missing, NA value means the houses have no alley access, we keep this feature**

# %% [markdown]
# ##### Fence column
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence

# %%
print(f"No of missing values of Fence column: {df_train['Fence'].isna().sum()} / {len(df_train)}  ({round(na_train['Fence'], 2)})")
# Out:
# No of missing values of Fence column: 1179 / 1460  (0.81)

# %% [markdown]
# **==>This is same as Alley, NA value means the houses have no Fence, we keep this feature**

# %% [markdown]
# ##### FireplaceQu
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace

# %%
print(f"No of missing values of FireplaceQu column: "
      f"{df_train['FireplaceQu'].isna().sum()} / {len(df_train)} ({round(na_train['FireplaceQu'], 2)})")
# Out:
# No of missing values of FireplaceQu column: 690 / 1460 (0.47)

# %% [markdown]
# **==>This is same as Alley, NA value means the houses have no Fireplace, we keep this feature**

# %% [markdown]
# ##### PoolQC
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool

# %%
print(f"No of missing values of PoolQC column: "
      f"{df_train['PoolQC'].isna().sum()} / {len(df_train)} ({round(na_train['PoolQC'], 2)})")
# Out:
# No of missing values of PoolQC column: 1453 / 1460 (1.0)

# %% [markdown]
# **==>This is same as Alley, NA value means the houses have no Pool, we keep this feature**

# %% [markdown]
# ##### MiscFeature
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None

# %%
print(f"No of missing values of MiscFeature column: "
      f"{df_train['MiscFeature'].isna().sum()} / {len(df_train)} ({round(na_train['MiscFeature'], 2)})")
# Out:
# No of missing values of MiscFeature column: 1406 / 1460 (0.96)

# %% [markdown]
# **==>This is not the same as Alley, NA value means None, we can remove this feature**

# %%
ignored_cols.append('MiscFeature')
ignored_cols
# Out:
# ['MiscFeature']

# %% [markdown]
# #### Missing cols 0-40%

# %% [markdown]
# Get columns with missing percentage greater than 0% and less than 40%

# %%
#get columns with missing percentage greater than 0% and less than 40%
missing_cols_lt_40 = set(na_train[na_train > 0].index) - cols_with_gt_40_missing
print(f"There are {len(missing_cols)} columns with missing percentage in range (0-0.4)")
# Out:
# There are 80 columns with missing percentage in range (0-0.4)

# %%
na_train[:10]
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageYrBlt     0.055479
# GarageCond      0.055479
# GarageType      0.055479
# GarageFinish    0.055479
# dtype: float64

# %% [markdown]
# Missing columns are numerical

# %%
numerical_missing_cols = set(missing_cols).intersection(set(numerical_cols))
numerical_missing_cols
# Out:
# {'1stFlrSF',
#  '2ndFlrSF',
#  '3SsnPorch',
#  'BedroomAbvGr',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'BsmtUnfSF',
#  'EnclosedPorch',
#  'Fireplaces',
#  'FullBath',
#  'GarageArea',
#  'GarageCars',
#  'GarageYrBlt',
#  'GrLivArea',
#  'HalfBath',
#  'KitchenAbvGr',
#  'LotArea',
#  'LotFrontage',
#  'LowQualFinSF',
#  'MSSubClass',
#  'MasVnrArea',
#  'MiscVal',
#  'MoSold',
#  'OpenPorchSF',
#  'OverallCond',
#  'OverallQual',
#  'PoolArea',
#  'SalePrice',
#  'ScreenPorch',
#  'TotRmsAbvGrd',
#  'TotalBsmtSF',
#  'WoodDeckSF',
#  'YearBuilt',
#  'YearRemodAdd',
#  'YrSold'}

# %% [markdown]
# Missing columns are categorical

# %%
categorical_missing_cols = set(missing_cols).intersection(set(categorical_cols))
categorical_missing_cols
# Out:
# {'Alley',
#  'BldgType',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'BsmtQual',
#  'CentralAir',
#  'Condition1',
#  'Condition2',
#  'Electrical',
#  'ExterCond',
#  'ExterQual',
#  'Exterior1st',
#  'Exterior2nd',
#  'Fence',
#  'FireplaceQu',
#  'Foundation',
#  'Functional',
#  'GarageCond',
#  'GarageFinish',
#  'GarageQual',
#  'GarageType',
#  'Heating',
#  'HeatingQC',
#  'HouseStyle',
#  'KitchenQual',
#  'LandContour',
#  'LandSlope',
#  'LotConfig',
#  'LotShape',
#  'MSZoning',
#  'MasVnrType',
#  'MiscFeature',
#  'Neighborhood',
#  'PavedDrive',
#  'PoolQC',
#  'RoofMatl',
#  'RoofStyle',
#  'SaleCondition',
#  'SaleType',
#  'Street',
#  'Utilities'}

# %% [markdown]
# ##### Features relevant Garage

# %% [markdown]
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# ['GarageYrBlt', 'GarageQual', 'GarageCond', 'GarageFinish', 'GarageType']

# %%
garage_features = ['GarageYrBlt', 'GarageQual', 'GarageCond', 'GarageFinish', 'GarageType']

# %%
print(f"The columns GarageFinish has {df_train['GarageFinish'].isna().sum()} missing values in total {len(df_train['GarageFinish'])}")
# Out:
# The columns GarageFinish has 81 missing values in total 1460

# %%
# Check features of garage with houses don't have garage
houses_no_garage = df_train[df_train['GarageFinish'].isna()][garage_features]
houses_no_garage.head()
# Out:
#     GarageYrBlt GarageQual GarageCond GarageFinish GarageType
# Id
# 40          NaN        NaN        NaN          NaN        NaN
# 49          NaN        NaN        NaN          NaN        NaN
# 79          NaN        NaN        NaN          NaN        NaN
# 89          NaN        NaN        NaN          NaN        NaN
# 90          NaN        NaN        NaN          NaN        NaN

# %%
#Count non-NA values in garage features on houses that have no garage
houses_no_garage.notna().sum()
# Out:
# GarageYrBlt     0
# GarageQual      0
# GarageCond      0
# GarageFinish    0
# GarageType      0
# dtype: int64

# %%
df_train['GarageFinish'].isna().sum()
# Out:
# 81

# %% [markdown]
# **==>Conclusion: Houses have no garage (GarageFinish=NA), its garage features also missing values**
#
# It is a type of missing data - structural missing data as a special case of data that is missing not at random

# %% [markdown]
# ##### Features relevant Basement

# %% [markdown]
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area

# %%
bmstFeatures = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF']

# %%
df_train[bmstFeatures].isna().sum()
# Out:
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinSF1       0
# BsmtFinType2    38
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# dtype: int64

# %% [markdown]
# **=> NA is no basement (a category), we dont apply any imputation for basement features**

# %% [markdown]
# ##### Other columns

# %%
missing_others = missing_cols_lt_40 - set(bmstFeatures) - set(garage_features)
missing_others
# Out:
# {'Electrical', 'LotFrontage', 'MasVnrArea', 'MasVnrType'}

# %% [markdown]
# ##### Electrical

# %%
check_missing('Electrical')
# Out:
# The column Electrical has 1 missing values in total 1460 (0.0007)

# %%
print(f"Number of missing values on Electrical column in test set: {df_test['Electrical'].isna().sum()}")
# Out:
# Number of missing values on Electrical column in test set: 0

# %% [markdown]
# **=> Remove the row which missing Electrical in train set**
#
# The missing Electrical only happen on train set

# %%
org_df_train = df_train.copy()
df_train = df_train[df_train['Electrical'].notna()]
df_train.reset_index(inplace=True, drop=True)

# %%
df_train['Electrical'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### MasVnrType
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone

# %%
check_missing('MasVnrType')
# Out:
# The column MasVnrType has 8 missing values in total 1459 (0.0055)

# %%
df_train['MasVnrType'].value_counts(ascending=False, dropna=False)
# Out:
# None       863
# BrkFace    445
# Stone      128
# BrkCmn      15
# NaN          8
# Name: MasVnrType, dtype: int64

# %% [markdown]
# Imputation method for MasVnrType colunm is Most Frequency

# %%
df_train['MasVnrType'] = df_train['MasVnrType'].fillna('None')
df_train['MasVnrType'].value_counts(ascending=False, dropna=False)
# Out:
# None       871
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df_train[(df_train['MasVnrArea'].isna()) | (df_train['MasVnrType'].isna())][['MasVnrArea', 'MasVnrType']]
# Out:
#       MasVnrArea MasVnrType
# 234          NaN       None
# 529          NaN       None
# 650          NaN       None
# 936          NaN       None
# 973          NaN       None
# 977          NaN       None
# 1243         NaN       None
# 1278         NaN       None

# %% [markdown]
# Check MasVnrArea where MasVnrType is None

# %%
df_train[df_train['MasVnrType'] == 'None']['MasVnrArea'].value_counts(ascending=False)
# Out:
# 0.0      858
# 1.0        2
# 288.0      1
# 344.0      1
# 312.0      1
# Name: MasVnrArea, dtype: int64

# %% [markdown]
# ##### MasVnrArea
# MasVnrArea: Masonry veneer area in square feet

# %%
check_missing('MasVnrArea')
# Out:
# The column MasVnrArea has 8 missing values in total 1459 (0.0055)

# %%
print(f"Number of missing values on MasVnrArea column in test set: {df_test['MasVnrArea'].isna().sum()}")
# Out:
# Number of missing values on MasVnrArea column in test set: 15

# %%
df_train['MasVnrArea'].value_counts(ascending=False)
# Out:
# 0.0      860
# 180.0      8
# 72.0       8
# 108.0      8
# 120.0      7
#         ...
# 562.0      1
# 89.0       1
# 921.0      1
# 762.0      1
# 119.0      1
# Name: MasVnrArea, Length: 327, dtype: int64

# %%
plot_distributions(df_train['MasVnrArea'])
# Out:
# C:\Python3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Impute NA value in MasVnrArea = 0**

# %%
df_train['MasVnrArea'] = df_train['MasVnrArea'].fillna(0)
df_train['MasVnrArea'].isna().sum()
# Out:
# 0

# %%
plot_distributions(df_train['MasVnrArea'])
# Out:
# C:\Python3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Python3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##### LotFrontage
# LotFrontage: Linear feet of street connected to property

# %%
df_train['LotFrontage'].head()
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# Name: LotFrontage, dtype: float64

# %%
check_missing('LotFrontage')
# Out:
# The column LotFrontage has 259 missing values in total 1459 (0.1775)

# %%
df_train['LotFrontage'].describe()
# Out:
# count    1200.000000
# mean       70.047500
# std        24.294727
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %% [markdown]
# LotFrontage after removing NA

# %% [markdown]
# **The LotFrontage is normal distribution**

# %% [markdown]
# Using KNN imputer to impute missing value in LotFrontage

# %%
corr = corr_matrix.loc['LotFrontage'].sort_values()
high_corr = pd.concat([corr[(corr < -0.2)], corr[(corr > 0.2)]])
high_corr
# Out:
# MSSubClass     -0.39
# PoolArea        0.21
# BsmtFinSF1      0.23
# OverallQual     0.25
# BedroomAbvGr    0.26
# Fireplaces      0.27
# GarageCars      0.29
# GarageArea      0.34
# TotRmsAbvGrd    0.35
# SalePrice       0.35
# TotalBsmtSF     0.39
# GrLivArea       0.40
# LotArea         0.43
# 1stFlrSF        0.46
# LotFrontage     1.00
# Name: LotFrontage, dtype: float64

# %%
cols_to_use = high_corr.index
cols_to_use
# Out:
# Index(['MSSubClass', 'PoolArea', 'BsmtFinSF1', 'OverallQual', 'BedroomAbvGr',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'TotRmsAbvGrd', 'SalePrice',
#        'TotalBsmtSF', 'GrLivArea', 'LotArea', '1stFlrSF', 'LotFrontage'],
#       dtype='object')

# %%
X_train_lf = df_train[cols_to_use]
X_train_lf.head()
# Out:
#    MSSubClass  PoolArea  BsmtFinSF1  OverallQual  BedroomAbvGr  Fireplaces  \
# 0          60         0       706.0            7             3           0
# 1          20         0       978.0            6             3           1
# 2          60         0       486.0            7             3           1
# 3          70         0       216.0            7             3           1
# 4          60         0       655.0            8             4           1
#
#    GarageCars  GarageArea  TotRmsAbvGrd  SalePrice  TotalBsmtSF  GrLivArea  \
# 0         2.0       548.0             8     208500        856.0       1710
# 1         2.0       460.0             6     181500       1262.0       1262
# 2         2.0       608.0             6     223500        920.0       1786
# 3         3.0       642.0             7     140000        756.0       1717
# 4         3.0       836.0             9     250000       1145.0       2198
#
#    LotArea  1stFlrSF  LotFrontage
# 0     8450       856         65.0
# 1     9600      1262         80.0
# 2    11250       920         68.0
# 3     9550       961         60.0
# 4    14260      1145         84.0

# %%
lotfrontage_imputer = KNNImputer(
    n_neighbors=5, # the number of neighbours K
    weights='distance', # the weighting factor
    metric='nan_euclidean', # the metric to find the neighbours
    add_indicator=False, # whether to add a missing indicator
)

# %%
lotfrontage_imputer.fit(X_train_lf)
# Out:
# KNNImputer(weights='distance')

# %%
df_train_lf = lotfrontage_imputer.transform(X_train_lf)
df_train_lf = pd.DataFrame(df_train_lf, columns=X_train_lf.columns)
df_train_lf.head()
# Out:
#    MSSubClass  PoolArea  BsmtFinSF1  OverallQual  BedroomAbvGr  Fireplaces  \
# 0        60.0       0.0       706.0          7.0           3.0         0.0
# 1        20.0       0.0       978.0          6.0           3.0         1.0
# 2        60.0       0.0       486.0          7.0           3.0         1.0
# 3        70.0       0.0       216.0          7.0           3.0         1.0
# 4        60.0       0.0       655.0          8.0           4.0         1.0
#
#    GarageCars  GarageArea  TotRmsAbvGrd  SalePrice  TotalBsmtSF  GrLivArea  \
# 0         2.0       548.0           8.0   208500.0        856.0     1710.0
# 1         2.0       460.0           6.0   181500.0       1262.0     1262.0
# 2         2.0       608.0           6.0   223500.0        920.0     1786.0
# 3         3.0       642.0           7.0   140000.0        756.0     1717.0
# 4         3.0       836.0           9.0   250000.0       1145.0     2198.0
#
#    LotArea  1stFlrSF  LotFrontage
# 0   8450.0     856.0         65.0
# 1   9600.0    1262.0         80.0
# 2  11250.0     920.0         68.0
# 3   9550.0     961.0         60.0
# 4  14260.0    1145.0         84.0

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_train['LotFrontage'].plot(kind='kde', ax=ax, color='blue')
df_train_lf['LotFrontage'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['LotFrontage original', 'LotFrontage with KNN imputer']
ax.legend(lines, labels, loc='best')
plt.title('Variable LotFrontage distribution after KNN imputation')
plt.show()

# %%
df_train['LotFrontage'] = df_train_lf['LotFrontage']
df_train['LotFrontage'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Categorical encoding

# %% [markdown]
# Get categorical varibles under numeric

# %%
for col in numerical_cols:
    if len(df_train[col].value_counts()) < 30:
        print(f"The feature {col} has {len(df_train[col].unique())} unique values below:")
        print(f"\t\t {df_train[col].unique()}")
# Out:
# The feature MSSubClass has 15 unique values below:
# 		 [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# The feature OverallQual has 10 unique values below:
# 		 [ 7  6  8  5  9  4 10  3  1  2]
# The feature OverallCond has 9 unique values below:
# 		 [5 8 6 7 4 2 3 9 1]
# The feature LowQualFinSF has 24 unique values below:
# 		 [  0 360 513 234 528 572 144 392 371 390 420 473 156 515  80  53 232 481
#  120 514 397 479 205 384]
# The feature BsmtFullBath has 4 unique values below:
# 		 [1. 0. 2. 3.]
# The feature BsmtHalfBath has 3 unique values below:
# 		 [0. 1. 2.]
# The feature FullBath has 4 unique values below:
# 		 [2 1 3 0]
# The feature HalfBath has 3 unique values below:
# 		 [1 0 2]
# The feature BedroomAbvGr has 8 unique values below:
# 		 [3 4 1 2 0 5 6 8]
# The feature KitchenAbvGr has 4 unique values below:
# 		 [1 2 3 0]
# The feature TotRmsAbvGrd has 12 unique values below:
# 		 [ 8  6  7  9  5 11  4 10 12  3  2 14]
# The feature Fireplaces has 4 unique values below:
# 		 [0 1 2 3]
# The feature GarageCars has 5 unique values below:
# 		 [2. 3. 1. 0. 4.]
# The feature 3SsnPorch has 20 unique values below:
# 		 [  0 320 407 130 180 168 140 508 238 245 196 144 182 162  23 216  96 153
#  290 304]
# The feature PoolArea has 8 unique values below:
# 		 [  0 512 648 576 555 480 519 738]
# The feature MiscVal has 21 unique values below:
# 		 [    0   700   350   500   400   480   450 15500  1200   800  2000   600
#   3500  1300    54   620   560  1400  8300  1150  2500]
# The feature MoSold has 12 unique values below:
# 		 [ 2  5  9 12 10  8 11  4  1  7  3  6]
# The feature YrSold has 5 unique values below:
# 		 [2008 2007 2006 2009 2010]

# %%
#Check unique values of all categorical features
features_more_10_cate = []
for col in categorical_cols:
    no_uniq_value = df_train[col].unique()
    print(f"The feature {col} has {len(no_uniq_value)} unique values below:")
    print(f"\t\t {no_uniq_value}")
    if len(no_uniq_value) > 10:
        features_more_10_cate.append(col)
# Out:
# The feature MSZoning has 5 unique values below:
# 		 ['RL' 'RM' 'C (all)' 'FV' 'RH']
# The feature Street has 2 unique values below:
# 		 ['Pave' 'Grvl']
# The feature Alley has 3 unique values below:
# 		 [nan 'Grvl' 'Pave']
# The feature LotShape has 4 unique values below:
# 		 ['Reg' 'IR1' 'IR2' 'IR3']
# The feature LandContour has 4 unique values below:
# 		 ['Lvl' 'Bnk' 'Low' 'HLS']
# The feature Utilities has 2 unique values below:
# 		 ['AllPub' 'NoSeWa']
# The feature LotConfig has 5 unique values below:
# 		 ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# The feature LandSlope has 3 unique values below:
# 		 ['Gtl' 'Mod' 'Sev']
# The feature Neighborhood has 25 unique values below:
# 		 ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# The feature Condition1 has 9 unique values below:
# 		 ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# The feature Condition2 has 8 unique values below:
# 		 ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# The feature BldgType has 5 unique values below:
# 		 ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# The feature HouseStyle has 8 unique values below:
# 		 ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# The feature RoofStyle has 6 unique values below:
# 		 ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# The feature RoofMatl has 8 unique values below:
# 		 ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']
# The feature Exterior1st has 15 unique values below:
# 		 ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
# The feature Exterior2nd has 16 unique values below:
# 		 ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']
# The feature MasVnrType has 4 unique values below:
# 		 ['BrkFace' 'None' 'Stone' 'BrkCmn']
# The feature ExterQual has 4 unique values below:
# 		 ['Gd' 'TA' 'Ex' 'Fa']
# The feature ExterCond has 5 unique values below:
# 		 ['TA' 'Gd' 'Fa' 'Po' 'Ex']
# The feature Foundation has 6 unique values below:
# 		 ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']
# The feature BsmtQual has 5 unique values below:
# 		 ['Gd' 'TA' 'Ex' nan 'Fa']
# The feature BsmtCond has 5 unique values below:
# 		 ['TA' 'Gd' nan 'Fa' 'Po']
# The feature BsmtExposure has 5 unique values below:
# 		 ['No' 'Gd' 'Mn' 'Av' nan]
# The feature BsmtFinType1 has 7 unique values below:
# 		 ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
# The feature BsmtFinType2 has 7 unique values below:
# 		 ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
# The feature Heating has 6 unique values below:
# 		 ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']
# The feature HeatingQC has 5 unique values below:
# 		 ['Ex' 'Gd' 'TA' 'Fa' 'Po']
# The feature CentralAir has 2 unique values below:
# 		 ['Y' 'N']
# The feature Electrical has 5 unique values below:
# 		 ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
# The feature KitchenQual has 4 unique values below:
# 		 ['Gd' 'TA' 'Ex' 'Fa']
# The feature Functional has 7 unique values below:
# 		 ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev']
# The feature FireplaceQu has 6 unique values below:
# 		 [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
# The feature GarageType has 7 unique values below:
# 		 ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# The feature GarageFinish has 4 unique values below:
# 		 ['RFn' 'Unf' 'Fin' nan]
# The feature GarageQual has 6 unique values below:
# 		 ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
# The feature GarageCond has 6 unique values below:
# 		 ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']
# The feature PavedDrive has 3 unique values below:
# 		 ['Y' 'N' 'P']
# The feature PoolQC has 4 unique values below:
# 		 [nan 'Ex' 'Fa' 'Gd']
# The feature Fence has 5 unique values below:
# 		 [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
# The feature MiscFeature has 5 unique values below:
# 		 [nan 'Shed' 'Gar2' 'Othr' 'TenC']
# The feature SaleType has 9 unique values below:
# 		 ['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth']
# The feature SaleCondition has 6 unique values below:
# 		 ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family']

# %%
features_more_10_cate
# Out:
# ['Neighborhood', 'Exterior1st', 'Exterior2nd']

# %%
len(df_train['Neighborhood'].unique())
# Out:
# 25

# %%
for var in features_more_10_cate:
    fig = plt.figure()
    fig = df_train.groupby([var])['SalePrice'].mean().plot()
    fig.set_title(f'Relationship between {var} and SalePrice')
    fig.set_ylabel('Mean Survival')
    plt.show()

# %% [markdown]
# #### Ordered encoding
# ['Neighborhood', 'Exterior1st', 'Exterior2nd']

# %% [markdown]
# ##### Neighborhood, Exterior1st and Exterior2nd
# This feature has 25 categories, and this feature affects to Target(SalePrice).
# So we use Ordered encoding.
#
# Advantages
#
#     - Capture information within the category, therefore creating more predictive features
#     - Create a monotonic relationship between the variable and the target, therefore suitable for linear models
#     - Do not expand the feature space
#
# Limitations
#
#     - Prone to cause over-fitting

# %%
ordinal_enc = OrdinalEncoder(
    # NOTE that we indicate ordered in the encoding_method, otherwise it assings numbers arbitrarily
    encoding_method='ordered',
    variables=['Neighborhood', 'Exterior1st', 'Exterior2nd'])

# %%
X_enc_train = df_train.drop(columns='SalePrice')
Y_enc_train = df_train['SalePrice']

# %%
ordinal_enc.fit(X_enc_train, Y_enc_train)
ordinal_enc.encoder_dict_
# Out:
# {'Neighborhood': {'MeadowV': 0,
#   'IDOTRR': 1,
#   'BrDale': 2,
#   'BrkSide': 3,
#   'Edwards': 4,
#   'OldTown': 5,
#   'Sawyer': 6,
#   'Blueste': 7,
#   'SWISU': 8,
#   'NPkVill': 9,
#   'NAmes': 10,
#   'Mitchel': 11,
#   'SawyerW': 12,
#   'NWAmes': 13,
#   'Gilbert': 14,
#   'Blmngtn': 15,
#   'CollgCr': 16,
#   'Crawfor': 17,
#   'ClearCr': 18,
#   'Somerst': 19,
#   'Veenker': 20,
#   'Timber': 21,
#   'StoneBr': 22,
#   'NridgHt': 23,
#   'NoRidge': 24},
#  'Exterior1st': {'BrkComm': 0,
#   'AsphShn': 1,
#   'CBlock': 2,
#   'AsbShng': 3,
#   'MetalSd': 4,
#   'Wd Sdng': 5,
#   'WdShing': 6,
#   'Stucco': 7,
#   'HdBoard': 8,
#   'Plywood': 9,
#   'BrkFace': 10,
#   'VinylSd': 11,
#   'CemntBd': 12,
#   'Stone': 13,
#   'ImStucc': 14},
#  'Exterior2nd': {'CBlock': 0,
#   'AsbShng': 1,
#   'Brk Cmn': 2,
#   'AsphShn': 3,
#   'Wd Sdng': 4,
#   'MetalSd': 5,
#   'Stucco': 6,
#   'Stone': 7,
#   'Wd Shng': 8,
#   'HdBoard': 9,
#   'Plywood': 10,
#   'BrkFace': 11,
#   'VinylSd': 12,
#   'CmentBd': 13,
#   'ImStucc': 14,
#   'Other': 15}}

# %%
X_enc_train = ordinal_enc.transform(X_enc_train)
X_enc_train[features_more_10_cate]
# Out:
#       Neighborhood  Exterior1st  Exterior2nd
# 0               16           11           12
# 1               20            4            5
# 2               16           11           12
# 3               17            5            8
# 4               24           11           12
# ...            ...          ...          ...
# 1454            14           11           12
# 1455            13            9           10
# 1456            17           12           13
# 1457            10            4            5
# 1458             4            8            9
#
# [1459 rows x 3 columns]
